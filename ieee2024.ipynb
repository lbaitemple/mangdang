# %%
# %%bash
#
# ## cop gemini credential
# cp -r .gemini ~/.gemini
#
# ## setup sound conf
# bash ./create_asound_conf.sh
#
# ## install audio
# sudo apt-get install -y python3-pyaudio
# sudo apt-get install ffmpeg portaudio19-dev -y
#
# ## install python library
# pip uninstall pycrypto
# pip install opencv-python-headless ipywidgets opencv-python
# pip install pydub pyaudio pydub pycryptodome
# Out:
# asound.conf file created at ~/.asoundrc
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Suggested packages:
#   python-pyaudio-doc
# The following NEW packages will be installed:
#   python3-pyaudio
# 0 upgraded, 1 newly installed, 0 to remove and 3 not upgraded.
# Need to get 25.5 kB of archives.
# After this operation, 117 kB of additional disk space will be used.
# Get:1 http://ports.ubuntu.com/ubuntu-ports jammy/universe arm64 python3-pyaudio arm64 0.2.11-1.3ubuntu1 [25.5 kB]
# Fetched 25.5 kB in 0s (65.7 kB/s)
# Selecting previously unselected package python3-pyaudio.
# (Reading database ... 199847 files and directories currently installed.)
# Preparing to unpack .../python3-pyaudio_0.2.11-1.3ubuntu1_arm64.deb ...
# Unpacking python3-pyaudio (0.2.11-1.3ubuntu1) ...
# Setting up python3-pyaudio (0.2.11-1.3ubuntu1) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ...
